# %%
import pandas as pd
import numpy as np

# %%
movie_data=pd.read_csv("/content/movies.csv")
movie_data_1=pd.read_csv("/content/links.csv")
movie_data_2=pd.read_csv("/content/ratings.csv")
movie_data_3=pd.read_csv("/content/tags.csv")

# %%
movie_data_2.shape
# Out:
# (100836, 4)

# %%
movie_data.shape
# Out:
# (9742, 3)

# %%
movie_data_1.shape
# Out:
# (9742, 3)

# %%
movie_data_3.shape
# Out:
# (3683, 4)

# %%
movie_data_2['userId'].unique().sum()
# Out:
# 186355

# %%
movie_data.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie_data_1.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
# Filter the DataFrame for the movie "Matrix, The (1999)"
matrix_tags = movie_data_3.loc[movie_data_3['movieId'].isin(filtered_movies[filtered_movies['title'] == 'Matrix, The (1999)']['movieId'])]

# Display the result
print("Tags submitted by users to 'Matrix, The (1999)':")
print(matrix_tags[['tag']])
# Out:
# Tags submitted by users to 'Matrix, The (1999)':
#                      tag
# 815         martial arts
# 816               sci-fi
# 1646  alternate universe
# 2794          philosophy
# 2795    post apocalyptic

# %%
movie_data_2.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
movie_data_3.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
# Assuming movie_data is your DataFrame with movie information
terminator_2_movie = movie_data[movie_data['title'] == 'Terminator 2: Judgment Day (1991)']

# Display the movie information to find the movieId
print(terminator_2_movie)
# Out:
#      movieId                              title         genres
# 507      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi

# %%
movie_data_3.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
# Assuming movieId for "Terminator 2: Judgment Day (1991)" is available in your dataset
terminator_2_movie_id = 589

# Filter ratings for the specified movie
terminator_2_ratings = movie_data_2[movie_data_2['movieId'] == terminator_2_movie_id]

# Calculate the average user rating
average_rating = terminator_2_ratings['rating'].mean()

# Display the average rating
print(f"Average rating for 'Terminator 2: Judgment Day (1991)': {average_rating}")
# Out:
# Average rating for 'Terminator 2: Judgment Day (1991)': 3.970982142857143

# %%
# Find the movie with the highest average user rating
most_popular_movie = filtered_movies[filtered_movies['rating_mean'] == filtered_movies['rating_mean'].max()]

# Display the result
print("The most popular movie based on average user ratings is:")
print(most_popular_movie[['title', 'rating_mean']])
# Out:
# The most popular movie based on average user ratings is:
#                                 title  rating_mean
# 277  Shawshank Redemption, The (1994)     4.429022

# %%
# Display the column names in your DataFrame
print(movie_data_2.columns)
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
# Assuming you have a DataFrame named 'movie_data_3'
# Search for the movieId for "Fight Club (1999)"
fight_club_movie_id = movie_data[movie_data['title'].str.contains('Fight Club')]['movieId'].iloc[0]

print(f"The movieId for 'Fight Club (1999)' is: {fight_club_movie_id}")
# Out:
# The movieId for 'Fight Club (1999)' is: 2959

# %%
import matplotlib.pyplot as plt

# Assuming movieId for "Fight Club (1999)" is available in your dataset
fight_club_movie_id = 2959

# Filter ratings for the specified movie using .loc
fight_club_ratings = movie_data_2.loc[movie_data_2['movieId'] == fight_club_movie_id]

# Check if any ratings are available for the specified movie
if not fight_club_ratings.empty:
    # Plotting a histogram of user ratings
    plt.figure(figsize=(10, 6))
    plt.hist(fight_club_ratings['rating'], bins=5, edgecolor='black')
    plt.title('User Ratings Distribution for "Fight Club (1999)"')
    plt.xlabel('Rating')
    plt.ylabel('Frequency')
    plt.show()
else:
    print("No ratings found for 'Fight Club (1999)'.")

# %%
# Filter the DataFrame for the movie "Matrix, The (1999)"
matrix_tags = movie_data_3.loc[movie_data_3['movieId'].isin(filtered_movies[filtered_movies['title'] == 'Matrix, The (1999)']['movieId'])]

# Display the result
print("Tags submitted by users to 'Matrix, The (1999)':")
print(matrix_tags[['tag']])
# Out:
# Tags submitted by users to 'Matrix, The (1999)':
#                      tag
# 815         martial arts
# 816               sci-fi
# 1646  alternate universe
# 2794          philosophy
# 2795    post apocalyptic

# %%
# Filter the DataFrame for Sci-Fi movies
sci_fi_movies = filtered_movies[filtered_movies['genres'].str.contains('Sci-Fi', case=False)]

# Sort the Sci-Fi movies DataFrame by rating count in descending order
sorted_sci_fi_movies = sci_fi_movies.sort_values(by='rating_count', ascending=False)

# Extract the title of the third most popular Sci-Fi movie
third_most_popular_sci_fi_movie = sorted_sci_fi_movies.iloc[2]['title']

# Display the result
print("The third most popular Sci-Fi movie based on number of user ratings is:", third_most_popular_sci_fi_movie)
# Out:
# The third most popular Sci-Fi movie based on number of user ratings is: Jurassic Park (1993)

# %%
# Assuming 'sorted_sci_fi_movies' is a DataFrame sorted by popularity
# Assuming the column names are 'movieId' and 'title'

# Get the movieId of the third most popular sci-fi movie
third_most_popular_sci_fi_movie_id = sorted_sci_fi_movies.iloc[0]['movieId']

print(f"The movieId for the third most popular sci-fi movie is: {third_most_popular_sci_fi_movie_id}")
# Out:
# The movieId for the third most popular sci-fi movie is: 2571

# %%
links_data=pd.read_csv('/content/links.csv')

# %%
links_data.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
# Assuming you have a DataFrame named imdb_ratings_df with columns 'imdbId' and 'rating'
# Replace this with your actual IMDb ratings data

# Find the movieId with the highest IMDb rating
highest_imdb_rating_movieId = links_data.loc[links_data['imdbId'].idxmax(), 'movieId']

# Display the result
print("The movieId of the movie with the highest IMDb rating is:", highest_imdb_rating_movieId)
# Out:
# The movieId of the movie with the highest IMDb rating is: 193587

# %%
links_data
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
import pandas as pd

# Create a sample ratings DataFrame
ratings_data = {
    'userId': [1, 1, 2, 2, 3],
    'movieId': [101, 102, 101, 103, 102],
    'rating': [4.5, 3.0, 5.0, 2.5, 4.0],
    'timestamp': [1597896543, 1597896789, 1597897654, 1597897890, 1597898012],
    'imdbId': ['tt1234567', 'tt2345678', 'tt1234567', 'tt3456789', 'tt2345678']
}

ratings_df = pd.DataFrame(ratings_data)

# Create a sample links DataFrame
links_data = {
    'movieId': [101, 102, 103],
    'imdbId': ['tt1234567', 'tt2345678', 'tt3456789'],
    'tmdbId': [1111, 2222, 3333]
}

links_df = pd.DataFrame(links_data)

# Merge the two DataFrames
merged_df = pd.merge(ratings_df, links_df, on='imdbId', how='inner')

# Adding a sample 'genre' column with the correct length
merged_df['genre'] = ['Sci-Fi', 'Drama', 'Sci-Fi', 'Action', 'Drama']

# Display the merged DataFrame with the added 'genre' column
print(merged_df)
# Out:
#    userId  movieId_x  rating   timestamp     imdbId  movieId_y  tmdbId   genre
# 0       1        101     4.5  1597896543  tt1234567        101    1111  Sci-Fi
# 1       2        101     5.0  1597897654  tt1234567        101    1111   Drama
# 2       1        102     3.0  1597896789  tt2345678        102    2222  Sci-Fi
# 3       3        102     4.0  1597898012  tt2345678        102    2222  Action
# 4       2        103     2.5  1597897890  tt3456789        103    3333   Drama

# %%
# Filter for Sci-Fi movies
sci_fi_movies = merged_df[merged_df['genre'].str.contains('Sci-Fi', case=False)]

# Find the movieId with the highest IMDb rating among Sci-Fi movies
highest_imdb_rating_sci_fi_movieId = sci_fi_movies.loc[sci_fi_movies['rating'].idxmax(), 'movieId_x']

# Display the result
print("The movieId of the Sci-Fi movie with the highest IMDb rating is:", highest_imdb_rating_sci_fi_movieId)
# Out:
# The movieId of the Sci-Fi movie with the highest IMDb rating is: 101

# %%
import pandas as pd
linksdata=pd.read_csv("/content/links.csv")
linksdata
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Load the links data
links_df = pd.read_csv("path/to/links.csv")

# Assuming you have a DataFrame 'movies_with_50_ratings' from the mandatory operations
# Filter movies with more than 50 user ratings
movies_with_50_ratings = movies_with_50_ratings[movies_with_50_ratings['rating_count'] > 50]

# Function to scrape IMDb rating for a given IMDb ID
def scrape_imdb_rating(imdb_id):
  id = str(int(imdb_id))
  n_zeroes = 7 - len(id)
  new_id = "0"*n_zeroes + id
  URL = f"https://www.imdb.com/title/tt{new_id}/"
  request_header = {'Content-Type': 'text/html; charset=UTF-8',
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0',
                      'Accept-Encoding': 'gzip, deflate, br'}
  response = requests.FILL_IN_THE_BLANK(URL, headers=request_header)
  soup = FILL_IN_THE_BLANK(response.text)
  imdb_rating = soup.find('FILL_IN_THE_BLANK', attrs={'FILL_IN_THE_BLANK' : 'FILL_IN_THE_BLANK'})
  return imdb_rating.text if imdb_rating else np.nan
# Initialize variables for highest IMDb rating and corresponding movieId
highest_rating = 0
highest_rating_movieId = None

# Iterate over filtered movies and scrape IMDb ratings
for index, row in movies_with_50_ratings.iterrows():
    imdb_id = row['imdbId']
    movieId = row['movieId']

    # Scrape IMDb rating
    imdb_rating = scrape_imdb_rating(imdb_id)

    # Update highest rating if needed
    if imdb_rating and float(imdb_rating) > highest_rating:
        highest_rating = float(imdb_rating)
        highest_rating_movieId = movieId

# Print the result
print(f"The movieId with the highest IMDb rating is: {highest_rating_movieId} (IMDb Rating: {highest_rating})")

# %%
import requests
import numpy as np
from bs4 import FILL_IN_THE_BLANK

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    request_header = {'Content-Type': 'text/html; charset=UTF-8',
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0',
                      'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.FILL_IN_THE_BLANK(URL, headers=request_header)
    soup = FILL_IN_THE_BLANK(response.text)
    imdb_rating = soup.find('FILL_IN_THE_BLANK', attrs={'FILL_IN_THE_BLANK' : 'FILL_IN_THE_BLANK'})
    return imdb_rating.text if imdb_rating else np.nan

# %%
import pandas as pd

# Read the ratings CSV file into a DataFrame
ratings_df = pd.read_csv('ratings.csv')  # Replace 'ratings.csv' with your actual CSV file path

# 1. Group and Aggregate Ratings
grouped_ratings = ratings_df.groupby('movieId').agg({'rating': ['count', 'mean']}).reset_index()
grouped_ratings.columns = ['movieId', 'rating_count', 'avg_rating']

# 2. Filter Movies with More than 50 Ratings
movies_with_50_ratings = grouped_ratings[grouped_ratings['rating_count'] > 50]

# 3. Create a Subset of Data
subset_data = pd.merge(movies_with_50_ratings, ratings_df, on='movieId', how='inner')

# Display the subset of data
print(subset_data.head())
# Out:
#    movieId  rating_count  avg_rating  userId  rating   timestamp
# 0        1           215     3.92093       1     4.0   964982703
# 1        1           215     3.92093       5     4.0   847434962
# 2        1           215     3.92093       7     4.5  1106635946
# 3        1           215     3.92093      15     2.5  1510577970
# 4        1           215     3.92093      17     4.5  1305696483

# %%
subset_data.to_csv("subset_data.csv",index=False)

# %%
subset_data.shape
# Out:
# (40660, 6)

# %%
subset_data.columns
# Out:
# Index(['movieId', 'rating_count', 'avg_rating', 'userId', 'rating',
#        'timestamp'],
#       dtype='object')

# %%
import pandas as pd
import requests
import numpy as np
from bs4 import BeautifulSoup

# Assuming 'df' is your DataFrame
# Sort the DataFrame by 'rating_count' in descending order and select the top 50
top_50_ratings = subset_data.sort_values(by='rating_count', ascending=False).head(50)

def scrapper(imdbId):
    if pd.isna(imdbId):  # Check if IMDb ID is missing
        return np.nan

    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0" * n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"

    request_header = {
        'Content-Type': 'text/html; charset=UTF-8',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0',
        'Accept-Encoding': 'gzip, deflate, br'
    }

    try:
        response = requests.get(URL, headers=request_header)
        soup = BeautifulSoup(response.text, 'html.parser')
        imdb_rating = soup.find('span', attrs={'data-testid': 'hero-title-block__combined-rating'})
        return imdb_rating.text.strip() if imdb_rating else np.nan
    except Exception as e:
        print(f"Error scraping IMDb rating for movie with IMDb ID {imdbId}: {e}")
        return np.nan

# Apply the scraping function to get IMDb ratings for the top 50 rated movies
top_50_ratings['imdb_rating'] = top_50_ratings['movieId'].apply(scrapper)

# Display the result

# %%
top_50_ratings['rating'].max()
# Out:
# 5.0

# %%
top_50_ratings = top_50_ratings.drop(columns=['imdb_rating'])

# %%
top_50_ratings
# Out:
#       movieId  rating_count  avg_rating  userId  rating   timestamp
# 6838      356           329    4.164134     132     4.0  1157920481
# 6931      356           329    4.164134     319     4.0  1461352079
# 6873      356           329    4.164134     200     4.0  1229886266
# 6874      356           329    4.164134     201     5.0   939801781
# 6875      356           329    4.164134     202     5.0   974924053
# 6876      356           329    4.164134     205     4.0  1519900230
# 6877      356           329    4.164134     209     4.5  1524522179
# 6878      356           329    4.164134     211     4.5  1350912824
# 6879      356           329    4.164134     212     3.5  1490114873
# 6880      356           329    4.164134     215     3.5  1260908599
# 6881      356           329    4.164134     217     2.0   955943574
# 6882      356           329    4.164134     220     5.0  1230061657
# 6883      356           329    4.164134     221     3.5  1118247082
# ...

# %%
import requests
import numpy as np
from bs4 import BeautifulSoup

def scrapper(imdbId):
    if pd.isna(imdbId):  # Check if IMDb ID is missing
        return np.nan

    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0" * n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"

    request_header = {
        'Content-Type': 'text/html; charset=UTF-8',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0',
        'Accept-Encoding': 'gzip, deflate, br'
    }

    try:
        response = requests.get(URL, headers=request_header)
        print(f"IMDb ID: {imdbId}")
        print(f"Response status code: {response.status_code}")

        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            imdb_rating = soup.find('span', attrs={'data-testid': 'hero-title-block__combined-rating'})
            return imdb_rating.text.strip() if imdb_rating else np.nan
        else:
            print(f"Error: Received non-200 status code from IMDb: {response.status_code}")
            print(f"Response text: {response.text}")
            return np.nan
    except Exception as e:
        print(f"Error scraping IMDb rating for movie with IMDb ID {imdbId}: {e}")
        return np.nan

# Assuming you have a DataFrame named 'ratings_data'
subset_data['imdb_rating'] = subset_data['movieId'].apply(scrapper)
# Out:
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# Response status code: 200
# IMDb ID: 1
# ...
